# %%
import numpy as np
import pandas as pd


import torch

from sklearn.metrics.pairwise import cosine_similarity

from tqdm import tqdm
import ast

# %%
folder = '/dlabdata1/lugeon/'
name = 'websites_40000_5cat_emb.gz'
data = pd.read_csv(folder + name, 
                   header=0,
                   index_col = 0,
                   names=['emb', 'cat0'])

# %%
data = data[data.emb.notnull()]

# %%
data['emb'] = data.apply(lambda row: np.array(ast.literal_eval(row.emb)), axis=1)

# %%
data.head()
# Out:
#                                                  emb  cat0
# 0  [-0.0009275737561677632, -0.02362455401504249,...  Arts
# 1  [0.04585096571180555, -0.018588595920138888, 0...  Arts
# 2  [-0.009650490500710228, -0.02681940252130682, ...  Arts
# 4  [0.04253146113181601, 0.036278354878328284, 0....  Arts
# 5  [-0.07145182291666667, 0.0058917999267578125, ...  Arts

# %%
data.shape
# Out:
# (150192, 2)

# %%
data.cat0.value_counts()
# Out:
# Science      31772
# Computers    31235
# Kids         30741
# Arts         29484
# Sports       26960
# Name: cat0, dtype: int64

# %%
def categorize(s):
    if s == 'Kids':
        return 0
    if s == 'Science':
        return 1
    if s == 'Arts':
        return 2
    if s == 'Computers':
        return 3
    if s == 'Sports':
        return 4

# %%
data['cat_no'] = data.apply(lambda row: categorize(row.cat0), axis=1)

# %%
embeddings = np.concatenate(data.emb.values)

# %%
embedding_dim = 300
train_input = torch.tensor(embeddings)
train_input = torch.reshape(train_input, (-1, embedding_dim)).float()

# %%
train_input.shape
# Out:
# torch.Size([150192, 300])

# %%
cat_no = data.cat_no.values
train_target = torch.tensor(cat_no).long()

# %%
train_target.shape
# Out:
# torch.Size([150192])

# %%
id = np.arange(train_input.shape[0])
np.random.shuffle(id)

tr_id = id[:140_000]
te_id = id[140_000:]

train_input_ = train_input[tr_id]
test_input_ = train_input[te_id]

train_target_ = train_target[tr_id]
test_target_ = train_target[te_id]

# %%
data.iloc[tr_id].cat0.value_counts()
# Out:
# Science      29651
# Computers    29084
# Kids         28660
# Arts         27486
# Sports       25119
# Name: cat0, dtype: int64

# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch import optim
import time

# %%
class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        self.fc1 = nn.Linear(300, 300)
        self.fc2 = nn.Linear(300, 300)
        self.fc3 = nn.Linear(300, 100)
        self.fc4 = nn.Linear(100, 5)
        self.drop = nn.Dropout(0.1)

    def forward(self, x):
        x = self.fc1(x)
        #x = self.drop(x)
        x = self.fc2(F.relu(x))
        #x = self.drop(x)
        x = self.fc3(F.relu(x))
        #x = self.drop(x)
        x = self.fc4(F.relu(x))
        return x

# %%
def accuracy(output, target):
    nb_samples = output.shape[0]
    
    # Convert probability to decision
    output_class = torch.argmax(output, 1)
    
    nb_correct = (output_class == target).sum().item()
    return nb_correct / nb_samples

# %%
epochs = 400
batch_size = 64

model = Classifier()

# Loss
criterion = nn.CrossEntropyLoss()

# Optimizer
optimizer = optim.Adam(model.parameters(), 1e-4)

# Training the model
model.train(True)

for e in range(epochs):
    
    for input, target in zip(train_input_.split(batch_size), train_target_.split(batch_size)):
                             
        output = model(input)
        loss = criterion(output, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    model.train(False)
    tr_output = model(train_input_)
    te_output = model(test_input_)
    tr_loss = criterion(tr_output, train_target_)
    tr_acc = accuracy(tr_output, train_target_)
    te_acc = accuracy(te_output, test_target_)
    model.train(True)
    print("Epoch {}".format(e) +\
          " | Train loss : {:.3f}".format(tr_loss) +\
          " | Train accuracy : {:.3f}".format(tr_acc) +\
          " | Test accuracy : {:.3f}".format(te_acc))
# Out:
# Epoch 0 | Train loss : 1.022 | Train accuracy : 0.603 | Test accuracy : 0.605
# Epoch 1 | Train loss : 0.964 | Train accuracy : 0.624 | Test accuracy : 0.627
# Epoch 2 | Train loss : 0.936 | Train accuracy : 0.633 | Test accuracy : 0.636
# Epoch 3 | Train loss : 0.915 | Train accuracy : 0.639 | Test accuracy : 0.639
# Epoch 4 | Train loss : 0.899 | Train accuracy : 0.646 | Test accuracy : 0.643
# Epoch 5 | Train loss : 0.886 | Train accuracy : 0.650 | Test accuracy : 0.646
# Epoch 6 | Train loss : 0.874 | Train accuracy : 0.656 | Test accuracy : 0.651
# Epoch 7 | Train loss : 0.864 | Train accuracy : 0.660 | Test accuracy : 0.651
# Epoch 8 | Train loss : 0.856 | Train accuracy : 0.663 | Test accuracy : 0.656
# Epoch 9 | Train loss : 0.847 | Train accuracy : 0.666 | Test accuracy : 0.655
# Epoch 10 | Train loss : 0.839 | Train accuracy : 0.669 | Test accuracy : 0.658
# Epoch 11 | Train loss : 0.832 | Train accuracy : 0.672 | Test accuracy : 0.661
# Epoch 12 | Train loss : 0.826 | Train accuracy : 0.675 | Test accuracy : 0.663
# Epoch 13 | Train loss : 0.819 | Train accuracy : 0.677 | Test accuracy : 0.664
# Epoch 14 | Train loss : 0.813 | Train accuracy : 0.679 | Test accuracy : 0.666
# Epoch 15 | Train loss : 0.808 | Train accuracy : 0.681 | Test accuracy : 0.665
# Epoch 16 | Train loss : 0.802 | Train accuracy : 0.683 | Test accuracy : 0.665
# Epoch 17 | Train loss : 0.797 | Train accuracy : 0.685 | Test accuracy : 0.666
# Epoch 18 | Train loss : 0.792 | Train accuracy : 0.687 | Test accuracy : 0.666
# Epoch 19 | Train loss : 0.787 | Train accuracy : 0.689 | Test accuracy : 0.667
# Epoch 20 | Train loss : 0.782 | Train accuracy : 0.691 | Test accuracy : 0.669
# Epoch 21 | Train loss : 0.778 | Train accuracy : 0.693 | Test accuracy : 0.668
# Epoch 22 | Train loss : 0.773 | Train accuracy : 0.694 | Test accuracy : 0.669
# Epoch 23 | Train loss : 0.769 | Train accuracy : 0.696 | Test accuracy : 0.671
# Epoch 24 | Train loss : 0.765 | Train accuracy : 0.697 | Test accuracy : 0.670
# Epoch 25 | Train loss : 0.761 | Train accuracy : 0.699 | Test accuracy : 0.671
# Epoch 26 | Train loss : 0.757 | Train accuracy : 0.700 | Test accuracy : 0.671
# Epoch 27 | Train loss : 0.753 | Train accuracy : 0.702 | Test accuracy : 0.670
# Epoch 28 | Train loss : 0.750 | Train accuracy : 0.703 | Test accuracy : 0.670
# Epoch 29 | Train loss : 0.746 | Train accuracy : 0.705 | Test accuracy : 0.671
# Epoch 30 | Train loss : 0.743 | Train accuracy : 0.706 | Test accuracy : 0.671
# Epoch 31 | Train loss : 0.740 | Train accuracy : 0.707 | Test accuracy : 0.671
# Epoch 32 | Train loss : 0.736 | Train accuracy : 0.708 | Test accuracy : 0.672
# Epoch 33 | Train loss : 0.733 | Train accuracy : 0.710 | Test accuracy : 0.671
# Epoch 34 | Train loss : 0.730 | Train accuracy : 0.711 | Test accuracy : 0.672
# Epoch 35 | Train loss : 0.727 | Train accuracy : 0.712 | Test accuracy : 0.671
# Epoch 36 | Train loss : 0.724 | Train accuracy : 0.713 | Test accuracy : 0.671
# Epoch 37 | Train loss : 0.720 | Train accuracy : 0.714 | Test accuracy : 0.671
# Epoch 38 | Train loss : 0.717 | Train accuracy : 0.715 | Test accuracy : 0.671
# Epoch 39 | Train loss : 0.715 | Train accuracy : 0.716 | Test accuracy : 0.672
# Epoch 40 | Train loss : 0.712 | Train accuracy : 0.718 | Test accuracy : 0.672
# Epoch 41 | Train loss : 0.709 | Train accuracy : 0.719 | Test accuracy : 0.671
# Epoch 42 | Train loss : 0.706 | Train accuracy : 0.720 | Test accuracy : 0.671
# Epoch 43 | Train loss : 0.703 | Train accuracy : 0.721 | Test accuracy : 0.672
# Epoch 44 | Train loss : 0.700 | Train accuracy : 0.721 | Test accuracy : 0.672
# Epoch 45 | Train loss : 0.697 | Train accuracy : 0.722 | Test accuracy : 0.672
# Epoch 46 | Train loss : 0.695 | Train accuracy : 0.724 | Test accuracy : 0.673
# Epoch 47 | Train loss : 0.693 | Train accuracy : 0.724 | Test accuracy : 0.672
# Epoch 48 | Train loss : 0.690 | Train accuracy : 0.725 | Test accuracy : 0.673
# Epoch 49 | Train loss : 0.687 | Train accuracy : 0.727 | Test accuracy : 0.672
# Epoch 50 | Train loss : 0.685 | Train accuracy : 0.727 | Test accuracy : 0.673
# Epoch 51 | Train loss : 0.682 | Train accuracy : 0.728 | Test accuracy : 0.672
# Epoch 52 | Train loss : 0.680 | Train accuracy : 0.729 | Test accuracy : 0.672
# Epoch 53 | Train loss : 0.677 | Train accuracy : 0.730 | Test accuracy : 0.672
# Epoch 54 | Train loss : 0.675 | Train accuracy : 0.731 | Test accuracy : 0.671
# Epoch 55 | Train loss : 0.673 | Train accuracy : 0.732 | Test accuracy : 0.672
# Epoch 56 | Train loss : 0.671 | Train accuracy : 0.733 | Test accuracy : 0.672
# Epoch 57 | Train loss : 0.669 | Train accuracy : 0.733 | Test accuracy : 0.672
# Epoch 58 | Train loss : 0.668 | Train accuracy : 0.734 | Test accuracy : 0.672
# Epoch 59 | Train loss : 0.666 | Train accuracy : 0.735 | Test accuracy : 0.672
# Epoch 60 | Train loss : 0.664 | Train accuracy : 0.735 | Test accuracy : 0.673
# Epoch 61 | Train loss : 0.661 | Train accuracy : 0.736 | Test accuracy : 0.674
# Epoch 62 | Train loss : 0.659 | Train accuracy : 0.738 | Test accuracy : 0.673
# Epoch 63 | Train loss : 0.657 | Train accuracy : 0.738 | Test accuracy : 0.673
# Epoch 64 | Train loss : 0.656 | Train accuracy : 0.739 | Test accuracy : 0.673
# Epoch 65 | Train loss : 0.653 | Train accuracy : 0.740 | Test accuracy : 0.673
# Epoch 66 | Train loss : 0.651 | Train accuracy : 0.741 | Test accuracy : 0.672
# Epoch 67 | Train loss : 0.649 | Train accuracy : 0.741 | Test accuracy : 0.672
# Epoch 68 | Train loss : 0.647 | Train accuracy : 0.742 | Test accuracy : 0.672
# Epoch 69 | Train loss : 0.645 | Train accuracy : 0.742 | Test accuracy : 0.672
# Epoch 70 | Train loss : 0.642 | Train accuracy : 0.743 | Test accuracy : 0.673
# Epoch 71 | Train loss : 0.641 | Train accuracy : 0.744 | Test accuracy : 0.671
# Epoch 72 | Train loss : 0.640 | Train accuracy : 0.745 | Test accuracy : 0.672
# Epoch 73 | Train loss : 0.639 | Train accuracy : 0.745 | Test accuracy : 0.671
# Epoch 74 | Train loss : 0.637 | Train accuracy : 0.745 | Test accuracy : 0.672
# Epoch 75 | Train loss : 0.635 | Train accuracy : 0.746 | Test accuracy : 0.671
# Epoch 76 | Train loss : 0.633 | Train accuracy : 0.747 | Test accuracy : 0.671
# Epoch 77 | Train loss : 0.632 | Train accuracy : 0.746 | Test accuracy : 0.671
# Epoch 78 | Train loss : 0.631 | Train accuracy : 0.747 | Test accuracy : 0.670
# Epoch 79 | Train loss : 0.629 | Train accuracy : 0.748 | Test accuracy : 0.670
# Epoch 80 | Train loss : 0.627 | Train accuracy : 0.748 | Test accuracy : 0.671
# Epoch 81 | Train loss : 0.626 | Train accuracy : 0.749 | Test accuracy : 0.671
# Epoch 82 | Train loss : 0.624 | Train accuracy : 0.750 | Test accuracy : 0.671
# Epoch 83 | Train loss : 0.623 | Train accuracy : 0.750 | Test accuracy : 0.670
# Epoch 84 | Train loss : 0.621 | Train accuracy : 0.750 | Test accuracy : 0.671
# Epoch 85 | Train loss : 0.620 | Train accuracy : 0.751 | Test accuracy : 0.670
# Epoch 86 | Train loss : 0.619 | Train accuracy : 0.751 | Test accuracy : 0.671
# Epoch 87 | Train loss : 0.617 | Train accuracy : 0.752 | Test accuracy : 0.671
# Epoch 88 | Train loss : 0.616 | Train accuracy : 0.752 | Test accuracy : 0.671
# Epoch 89 | Train loss : 0.615 | Train accuracy : 0.752 | Test accuracy : 0.670
# Epoch 90 | Train loss : 0.613 | Train accuracy : 0.753 | Test accuracy : 0.670
# Epoch 91 | Train loss : 0.612 | Train accuracy : 0.753 | Test accuracy : 0.670
# Epoch 92 | Train loss : 0.611 | Train accuracy : 0.754 | Test accuracy : 0.670
# Epoch 93 | Train loss : 0.609 | Train accuracy : 0.754 | Test accuracy : 0.668
# Epoch 94 | Train loss : 0.608 | Train accuracy : 0.754 | Test accuracy : 0.669
# Epoch 95 | Train loss : 0.607 | Train accuracy : 0.755 | Test accuracy : 0.669
# Epoch 96 | Train loss : 0.607 | Train accuracy : 0.755 | Test accuracy : 0.669
# Epoch 97 | Train loss : 0.605 | Train accuracy : 0.755 | Test accuracy : 0.668
# Epoch 98 | Train loss : 0.604 | Train accuracy : 0.756 | Test accuracy : 0.668
# Epoch 99 | Train loss : 0.604 | Train accuracy : 0.756 | Test accuracy : 0.667
# Epoch 100 | Train loss : 0.602 | Train accuracy : 0.757 | Test accuracy : 0.669
# Epoch 101 | Train loss : 0.601 | Train accuracy : 0.757 | Test accuracy : 0.667
# Epoch 102 | Train loss : 0.600 | Train accuracy : 0.758 | Test accuracy : 0.667
# Epoch 103 | Train loss : 0.599 | Train accuracy : 0.757 | Test accuracy : 0.667
# Epoch 104 | Train loss : 0.599 | Train accuracy : 0.757 | Test accuracy : 0.666
# Epoch 105 | Train loss : 0.599 | Train accuracy : 0.757 | Test accuracy : 0.665
# Epoch 106 | Train loss : 0.597 | Train accuracy : 0.758 | Test accuracy : 0.666
# Epoch 107 | Train loss : 0.597 | Train accuracy : 0.758 | Test accuracy : 0.666
# Epoch 108 | Train loss : 0.595 | Train accuracy : 0.759 | Test accuracy : 0.665
# Epoch 109 | Train loss : 0.595 | Train accuracy : 0.759 | Test accuracy : 0.664
# Epoch 110 | Train loss : 0.594 | Train accuracy : 0.759 | Test accuracy : 0.665
# Epoch 111 | Train loss : 0.594 | Train accuracy : 0.759 | Test accuracy : 0.664
# Epoch 112 | Train loss : 0.593 | Train accuracy : 0.760 | Test accuracy : 0.664
# Epoch 113 | Train loss : 0.592 | Train accuracy : 0.760 | Test accuracy : 0.664
# Epoch 114 | Train loss : 0.591 | Train accuracy : 0.761 | Test accuracy : 0.663
# Epoch 115 | Train loss : 0.591 | Train accuracy : 0.761 | Test accuracy : 0.662
# Epoch 116 | Train loss : 0.590 | Train accuracy : 0.761 | Test accuracy : 0.663
# Epoch 117 | Train loss : 0.590 | Train accuracy : 0.761 | Test accuracy : 0.662
# Epoch 118 | Train loss : 0.590 | Train accuracy : 0.761 | Test accuracy : 0.661
# Epoch 119 | Train loss : 0.589 | Train accuracy : 0.761 | Test accuracy : 0.661
# Epoch 120 | Train loss : 0.590 | Train accuracy : 0.761 | Test accuracy : 0.662
# Epoch 121 | Train loss : 0.590 | Train accuracy : 0.761 | Test accuracy : 0.661
# Epoch 122 | Train loss : 0.591 | Train accuracy : 0.761 | Test accuracy : 0.660
# Epoch 123 | Train loss : 0.590 | Train accuracy : 0.761 | Test accuracy : 0.660
# Epoch 124 | Train loss : 0.591 | Train accuracy : 0.761 | Test accuracy : 0.659
# Epoch 125 | Train loss : 0.589 | Train accuracy : 0.761 | Test accuracy : 0.661
# Epoch 126 | Train loss : 0.590 | Train accuracy : 0.761 | Test accuracy : 0.659
# Epoch 127 | Train loss : 0.590 | Train accuracy : 0.761 | Test accuracy : 0.659
# Epoch 128 | Train loss : 0.593 | Train accuracy : 0.760 | Test accuracy : 0.658
# Epoch 129 | Train loss : 0.592 | Train accuracy : 0.760 | Test accuracy : 0.658
# Epoch 130 | Train loss : 0.594 | Train accuracy : 0.760 | Test accuracy : 0.658
# Epoch 131 | Train loss : 0.594 | Train accuracy : 0.760 | Test accuracy : 0.657
# Epoch 132 | Train loss : 0.594 | Train accuracy : 0.760 | Test accuracy : 0.657
# Epoch 133 | Train loss : 0.592 | Train accuracy : 0.761 | Test accuracy : 0.656
# Epoch 134 | Train loss : 0.593 | Train accuracy : 0.760 | Test accuracy : 0.655
# Epoch 135 | Train loss : 0.593 | Train accuracy : 0.760 | Test accuracy : 0.655
# Epoch 136 | Train loss : 0.594 | Train accuracy : 0.760 | Test accuracy : 0.652
# Epoch 137 | Train loss : 0.590 | Train accuracy : 0.761 | Test accuracy : 0.655
# Epoch 138 | Train loss : 0.589 | Train accuracy : 0.761 | Test accuracy : 0.656
# Epoch 139 | Train loss : 0.591 | Train accuracy : 0.760 | Test accuracy : 0.653
# Epoch 140 | Train loss : 0.590 | Train accuracy : 0.760 | Test accuracy : 0.654
# Epoch 141 | Train loss : 0.592 | Train accuracy : 0.759 | Test accuracy : 0.652
# Epoch 142 | Train loss : 0.589 | Train accuracy : 0.761 | Test accuracy : 0.655
# Epoch 143 | Train loss : 0.589 | Train accuracy : 0.760 | Test accuracy : 0.653
# Epoch 144 | Train loss : 0.589 | Train accuracy : 0.761 | Test accuracy : 0.654
# Epoch 145 | Train loss : 0.590 | Train accuracy : 0.761 | Test accuracy : 0.654
# Epoch 146 | Train loss : 0.589 | Train accuracy : 0.761 | Test accuracy : 0.653
# Epoch 147 | Train loss : 0.589 | Train accuracy : 0.760 | Test accuracy : 0.651
# Epoch 148 | Train loss : 0.589 | Train accuracy : 0.760 | Test accuracy : 0.650
# Epoch 149 | Train loss : 0.588 | Train accuracy : 0.761 | Test accuracy : 0.651
# Epoch 150 | Train loss : 0.585 | Train accuracy : 0.762 | Test accuracy : 0.651
# Epoch 151 | Train loss : 0.585 | Train accuracy : 0.762 | Test accuracy : 0.650
# Epoch 152 | Train loss : 0.591 | Train accuracy : 0.760 | Test accuracy : 0.650
# Epoch 153 | Train loss : 0.587 | Train accuracy : 0.761 | Test accuracy : 0.650
# Epoch 154 | Train loss : 0.586 | Train accuracy : 0.761 | Test accuracy : 0.651
# Epoch 155 | Train loss : 0.588 | Train accuracy : 0.761 | Test accuracy : 0.650
# Epoch 156 | Train loss : 0.587 | Train accuracy : 0.761 | Test accuracy : 0.650
# Epoch 157 | Train loss : 0.587 | Train accuracy : 0.761 | Test accuracy : 0.650
# Epoch 158 | Train loss : 0.586 | Train accuracy : 0.762 | Test accuracy : 0.649
# Epoch 159 | Train loss : 0.588 | Train accuracy : 0.761 | Test accuracy : 0.648
# Epoch 160 | Train loss : 0.589 | Train accuracy : 0.761 | Test accuracy : 0.649
# Epoch 161 | Train loss : 0.586 | Train accuracy : 0.762 | Test accuracy : 0.649
# Epoch 162 | Train loss : 0.587 | Train accuracy : 0.762 | Test accuracy : 0.648
# Epoch 163 | Train loss : 0.586 | Train accuracy : 0.762 | Test accuracy : 0.650
# Epoch 164 | Train loss : 0.588 | Train accuracy : 0.762 | Test accuracy : 0.648
# Epoch 165 | Train loss : 0.585 | Train accuracy : 0.763 | Test accuracy : 0.649
# Epoch 166 | Train loss : 0.585 | Train accuracy : 0.763 | Test accuracy : 0.651
# Epoch 167 | Train loss : 0.586 | Train accuracy : 0.762 | Test accuracy : 0.650
# Epoch 168 | Train loss : 0.586 | Train accuracy : 0.763 | Test accuracy : 0.650
# Epoch 169 | Train loss : 0.585 | Train accuracy : 0.763 | Test accuracy : 0.650
# Epoch 170 | Train loss : 0.584 | Train accuracy : 0.763 | Test accuracy : 0.651
# Epoch 171 | Train loss : 0.583 | Train accuracy : 0.763 | Test accuracy : 0.652
# Epoch 172 | Train loss : 0.584 | Train accuracy : 0.763 | Test accuracy : 0.652
# Epoch 173 | Train loss : 0.584 | Train accuracy : 0.764 | Test accuracy : 0.652
# Epoch 174 | Train loss : 0.584 | Train accuracy : 0.764 | Test accuracy : 0.652
# Epoch 175 | Train loss : 0.585 | Train accuracy : 0.763 | Test accuracy : 0.651
# Epoch 176 | Train loss : 0.583 | Train accuracy : 0.764 | Test accuracy : 0.653
# Epoch 177 | Train loss : 0.585 | Train accuracy : 0.763 | Test accuracy : 0.652
# Epoch 178 | Train loss : 0.583 | Train accuracy : 0.764 | Test accuracy : 0.652
# Epoch 179 | Train loss : 0.586 | Train accuracy : 0.764 | Test accuracy : 0.652
# Epoch 180 | Train loss : 0.585 | Train accuracy : 0.764 | Test accuracy : 0.652
# Epoch 181 | Train loss : 0.585 | Train accuracy : 0.764 | Test accuracy : 0.653
# Epoch 182 | Train loss : 0.587 | Train accuracy : 0.764 | Test accuracy : 0.653
# Epoch 183 | Train loss : 0.586 | Train accuracy : 0.765 | Test accuracy : 0.653
# Epoch 184 | Train loss : 0.587 | Train accuracy : 0.764 | Test accuracy : 0.654
# Epoch 185 | Train loss : 0.585 | Train accuracy : 0.765 | Test accuracy : 0.652
# Epoch 186 | Train loss : 0.588 | Train accuracy : 0.764 | Test accuracy : 0.652
# Epoch 187 | Train loss : 0.588 | Train accuracy : 0.764 | Test accuracy : 0.652
# Epoch 188 | Train loss : 0.588 | Train accuracy : 0.762 | Test accuracy : 0.653
# Epoch 189 | Train loss : 0.592 | Train accuracy : 0.763 | Test accuracy : 0.652
# Epoch 190 | Train loss : 0.590 | Train accuracy : 0.763 | Test accuracy : 0.652
# Epoch 191 | Train loss : 0.592 | Train accuracy : 0.762 | Test accuracy : 0.651
# Epoch 192 | Train loss : 0.593 | Train accuracy : 0.762 | Test accuracy : 0.652
# Epoch 193 | Train loss : 0.594 | Train accuracy : 0.762 | Test accuracy : 0.651
# Epoch 194 | Train loss : 0.595 | Train accuracy : 0.762 | Test accuracy : 0.652
# Epoch 195 | Train loss : 0.598 | Train accuracy : 0.761 | Test accuracy : 0.653
# Epoch 196 | Train loss : 0.600 | Train accuracy : 0.761 | Test accuracy : 0.653
# Epoch 197 | Train loss : 0.603 | Train accuracy : 0.759 | Test accuracy : 0.651
# Epoch 198 | Train loss : 0.604 | Train accuracy : 0.760 | Test accuracy : 0.651
# Epoch 199 | Train loss : 0.604 | Train accuracy : 0.760 | Test accuracy : 0.651
# Epoch 200 | Train loss : 0.605 | Train accuracy : 0.760 | Test accuracy : 0.652
# Epoch 201 | Train loss : 0.610 | Train accuracy : 0.758 | Test accuracy : 0.651
# Epoch 202 | Train loss : 0.612 | Train accuracy : 0.758 | Test accuracy : 0.651
# Epoch 203 | Train loss : 0.611 | Train accuracy : 0.758 | Test accuracy : 0.650
# Epoch 204 | Train loss : 0.610 | Train accuracy : 0.758 | Test accuracy : 0.651
# Epoch 205 | Train loss : 0.613 | Train accuracy : 0.757 | Test accuracy : 0.649
# Epoch 206 | Train loss : 0.613 | Train accuracy : 0.758 | Test accuracy : 0.649
# Epoch 207 | Train loss : 0.613 | Train accuracy : 0.758 | Test accuracy : 0.649
# Epoch 208 | Train loss : 0.614 | Train accuracy : 0.757 | Test accuracy : 0.648
# Epoch 209 | Train loss : 0.618 | Train accuracy : 0.757 | Test accuracy : 0.649
# Epoch 210 | Train loss : 0.617 | Train accuracy : 0.756 | Test accuracy : 0.646
# Epoch 211 | Train loss : 0.617 | Train accuracy : 0.757 | Test accuracy : 0.648
# Epoch 212 | Train loss : 0.618 | Train accuracy : 0.757 | Test accuracy : 0.646
# Epoch 213 | Train loss : 0.618 | Train accuracy : 0.757 | Test accuracy : 0.645
# Epoch 214 | Train loss : 0.618 | Train accuracy : 0.756 | Test accuracy : 0.645
# Epoch 215 | Train loss : 0.620 | Train accuracy : 0.758 | Test accuracy : 0.645
# Epoch 216 | Train loss : 0.618 | Train accuracy : 0.759 | Test accuracy : 0.645
# Epoch 217 | Train loss : 0.621 | Train accuracy : 0.757 | Test accuracy : 0.644
# Epoch 218 | Train loss : 0.618 | Train accuracy : 0.758 | Test accuracy : 0.645
# Epoch 219 | Train loss : 0.618 | Train accuracy : 0.757 | Test accuracy : 0.645
# Epoch 220 | Train loss : 0.618 | Train accuracy : 0.757 | Test accuracy : 0.644
# Epoch 221 | Train loss : 0.621 | Train accuracy : 0.756 | Test accuracy : 0.643
# Epoch 222 | Train loss : 0.621 | Train accuracy : 0.756 | Test accuracy : 0.644
# Epoch 223 | Train loss : 0.622 | Train accuracy : 0.756 | Test accuracy : 0.644
# Epoch 224 | Train loss : 0.623 | Train accuracy : 0.756 | Test accuracy : 0.644
# Epoch 225 | Train loss : 0.622 | Train accuracy : 0.756 | Test accuracy : 0.646
# Epoch 226 | Train loss : 0.625 | Train accuracy : 0.756 | Test accuracy : 0.644
# Epoch 227 | Train loss : 0.627 | Train accuracy : 0.756 | Test accuracy : 0.644
# Epoch 228 | Train loss : 0.631 | Train accuracy : 0.755 | Test accuracy : 0.643
# Epoch 229 | Train loss : 0.628 | Train accuracy : 0.756 | Test accuracy : 0.645
# Epoch 230 | Train loss : 0.626 | Train accuracy : 0.757 | Test accuracy : 0.644
# Epoch 231 | Train loss : 0.627 | Train accuracy : 0.756 | Test accuracy : 0.642
# Epoch 232 | Train loss : 0.618 | Train accuracy : 0.758 | Test accuracy : 0.646
# Epoch 233 | Train loss : 0.614 | Train accuracy : 0.760 | Test accuracy : 0.648
# Epoch 234 | Train loss : 0.612 | Train accuracy : 0.760 | Test accuracy : 0.645
# Epoch 235 | Train loss : 0.613 | Train accuracy : 0.760 | Test accuracy : 0.646
# Epoch 236 | Train loss : 0.614 | Train accuracy : 0.760 | Test accuracy : 0.646
# Epoch 237 | Train loss : 0.609 | Train accuracy : 0.761 | Test accuracy : 0.644
# Epoch 238 | Train loss : 0.613 | Train accuracy : 0.759 | Test accuracy : 0.644
# Epoch 239 | Train loss : 0.612 | Train accuracy : 0.761 | Test accuracy : 0.644
# Epoch 240 | Train loss : 0.615 | Train accuracy : 0.758 | Test accuracy : 0.642
# Epoch 241 | Train loss : 0.618 | Train accuracy : 0.758 | Test accuracy : 0.640
# Epoch 242 | Train loss : 0.619 | Train accuracy : 0.758 | Test accuracy : 0.640
# Epoch 243 | Train loss : 0.620 | Train accuracy : 0.759 | Test accuracy : 0.640
# Epoch 244 | Train loss : 0.625 | Train accuracy : 0.757 | Test accuracy : 0.640
# Epoch 245 | Train loss : 0.629 | Train accuracy : 0.757 | Test accuracy : 0.639
# Epoch 246 | Train loss : 0.632 | Train accuracy : 0.756 | Test accuracy : 0.638
# Epoch 247 | Train loss : 0.630 | Train accuracy : 0.756 | Test accuracy : 0.639
# Epoch 248 | Train loss : 0.640 | Train accuracy : 0.754 | Test accuracy : 0.636
# Epoch 249 | Train loss : 0.627 | Train accuracy : 0.757 | Test accuracy : 0.639
# Epoch 250 | Train loss : 0.645 | Train accuracy : 0.753 | Test accuracy : 0.636
# Epoch 251 | Train loss : 0.630 | Train accuracy : 0.756 | Test accuracy : 0.640
# Epoch 252 | Train loss : 0.632 | Train accuracy : 0.756 | Test accuracy : 0.638
# Epoch 253 | Train loss : 0.650 | Train accuracy : 0.752 | Test accuracy : 0.636
# Epoch 254 | Train loss : 0.631 | Train accuracy : 0.757 | Test accuracy : 0.640
# Epoch 255 | Train loss : 0.634 | Train accuracy : 0.757 | Test accuracy : 0.640
# Epoch 256 | Train loss : 0.637 | Train accuracy : 0.756 | Test accuracy : 0.642
# Epoch 257 | Train loss : 0.635 | Train accuracy : 0.756 | Test accuracy : 0.642
# Epoch 258 | Train loss : 0.627 | Train accuracy : 0.758 | Test accuracy : 0.645
# Epoch 259 | Train loss : 0.626 | Train accuracy : 0.758 | Test accuracy : 0.644
# Epoch 260 | Train loss : 0.634 | Train accuracy : 0.757 | Test accuracy : 0.643
# Epoch 261 | Train loss : 0.629 | Train accuracy : 0.758 | Test accuracy : 0.645
# Epoch 262 | Train loss : 0.630 | Train accuracy : 0.759 | Test accuracy : 0.645
# Epoch 263 | Train loss : 0.633 | Train accuracy : 0.758 | Test accuracy : 0.647
# Epoch 264 | Train loss : 0.633 | Train accuracy : 0.758 | Test accuracy : 0.643
# Epoch 265 | Train loss : 0.635 | Train accuracy : 0.757 | Test accuracy : 0.645
# Epoch 266 | Train loss : 0.639 | Train accuracy : 0.756 | Test accuracy : 0.643
# Epoch 267 | Train loss : 0.642 | Train accuracy : 0.756 | Test accuracy : 0.645
# Epoch 268 | Train loss : 0.652 | Train accuracy : 0.753 | Test accuracy : 0.644
# Epoch 269 | Train loss : 0.656 | Train accuracy : 0.753 | Test accuracy : 0.642
# Epoch 270 | Train loss : 0.662 | Train accuracy : 0.752 | Test accuracy : 0.643
# Epoch 271 | Train loss : 0.667 | Train accuracy : 0.752 | Test accuracy : 0.644
# Epoch 272 | Train loss : 0.679 | Train accuracy : 0.749 | Test accuracy : 0.642
# Epoch 273 | Train loss : 0.674 | Train accuracy : 0.750 | Test accuracy : 0.642
# Epoch 274 | Train loss : 0.678 | Train accuracy : 0.749 | Test accuracy : 0.642
# Epoch 275 | Train loss : 0.689 | Train accuracy : 0.748 | Test accuracy : 0.639
# Epoch 276 | Train loss : 0.680 | Train accuracy : 0.749 | Test accuracy : 0.642
# Epoch 277 | Train loss : 0.677 | Train accuracy : 0.750 | Test accuracy : 0.639
# Epoch 278 | Train loss : 0.690 | Train accuracy : 0.747 | Test accuracy : 0.639
# Epoch 279 | Train loss : 0.678 | Train accuracy : 0.750 | Test accuracy : 0.639
# Epoch 280 | Train loss : 0.685 | Train accuracy : 0.748 | Test accuracy : 0.637
# Epoch 281 | Train loss : 0.685 | Train accuracy : 0.748 | Test accuracy : 0.636
# Epoch 282 | Train loss : 0.701 | Train accuracy : 0.745 | Test accuracy : 0.635
# Epoch 283 | Train loss : 0.693 | Train accuracy : 0.747 | Test accuracy : 0.637
# Epoch 284 | Train loss : 0.703 | Train accuracy : 0.745 | Test accuracy : 0.634
# Epoch 285 | Train loss : 0.712 | Train accuracy : 0.743 | Test accuracy : 0.633
# Epoch 286 | Train loss : 0.714 | Train accuracy : 0.742 | Test accuracy : 0.632
# Epoch 287 | Train loss : 0.715 | Train accuracy : 0.742 | Test accuracy : 0.631
# Epoch 288 | Train loss : 0.719 | Train accuracy : 0.742 | Test accuracy : 0.628
# Epoch 289 | Train loss : 0.726 | Train accuracy : 0.740 | Test accuracy : 0.629
# Epoch 290 | Train loss : 0.737 | Train accuracy : 0.737 | Test accuracy : 0.625
# Epoch 291 | Train loss : 0.755 | Train accuracy : 0.735 | Test accuracy : 0.625
# Epoch 292 | Train loss : 0.744 | Train accuracy : 0.737 | Test accuracy : 0.626
# Epoch 293 | Train loss : 0.746 | Train accuracy : 0.737 | Test accuracy : 0.626
# Epoch 294 | Train loss : 0.747 | Train accuracy : 0.737 | Test accuracy : 0.626
# Epoch 295 | Train loss : 0.741 | Train accuracy : 0.739 | Test accuracy : 0.626
# Epoch 296 | Train loss : 0.733 | Train accuracy : 0.741 | Test accuracy : 0.629
# Epoch 297 | Train loss : 0.736 | Train accuracy : 0.741 | Test accuracy : 0.628
# Epoch 298 | Train loss : 0.740 | Train accuracy : 0.740 | Test accuracy : 0.628
# Epoch 299 | Train loss : 0.746 | Train accuracy : 0.739 | Test accuracy : 0.630
# Epoch 300 | Train loss : 0.720 | Train accuracy : 0.743 | Test accuracy : 0.634
# Epoch 301 | Train loss : 0.726 | Train accuracy : 0.742 | Test accuracy : 0.633
# Epoch 302 | Train loss : 0.708 | Train accuracy : 0.746 | Test accuracy : 0.635
# Epoch 303 | Train loss : 0.714 | Train accuracy : 0.746 | Test accuracy : 0.635
# Epoch 304 | Train loss : 0.713 | Train accuracy : 0.746 | Test accuracy : 0.637
# Epoch 305 | Train loss : 0.687 | Train accuracy : 0.750 | Test accuracy : 0.637
# Epoch 306 | Train loss : 0.692 | Train accuracy : 0.749 | Test accuracy : 0.638
# Epoch 307 | Train loss : 0.704 | Train accuracy : 0.748 | Test accuracy : 0.639
# Epoch 308 | Train loss : 0.735 | Train accuracy : 0.742 | Test accuracy : 0.636
# Epoch 309 | Train loss : 0.716 | Train accuracy : 0.745 | Test accuracy : 0.638
# Epoch 310 | Train loss : 0.706 | Train accuracy : 0.748 | Test accuracy : 0.641
# Epoch 311 | Train loss : 0.713 | Train accuracy : 0.748 | Test accuracy : 0.640
# Epoch 312 | Train loss : 0.715 | Train accuracy : 0.748 | Test accuracy : 0.641
# Epoch 313 | Train loss : 0.718 | Train accuracy : 0.747 | Test accuracy : 0.641
# Epoch 314 | Train loss : 0.709 | Train accuracy : 0.748 | Test accuracy : 0.640
# Epoch 315 | Train loss : 0.713 | Train accuracy : 0.748 | Test accuracy : 0.642
# Epoch 316 | Train loss : 0.701 | Train accuracy : 0.751 | Test accuracy : 0.643
# Epoch 317 | Train loss : 0.686 | Train accuracy : 0.754 | Test accuracy : 0.641
# Epoch 318 | Train loss : 0.697 | Train accuracy : 0.751 | Test accuracy : 0.641
# Epoch 319 | Train loss : 0.696 | Train accuracy : 0.751 | Test accuracy : 0.640
# Epoch 320 | Train loss : 0.690 | Train accuracy : 0.752 | Test accuracy : 0.641
# Epoch 321 | Train loss : 0.692 | Train accuracy : 0.753 | Test accuracy : 0.643
# Epoch 322 | Train loss : 0.712 | Train accuracy : 0.749 | Test accuracy : 0.639
# Epoch 323 | Train loss : 0.704 | Train accuracy : 0.751 | Test accuracy : 0.642
# Epoch 324 | Train loss : 0.692 | Train accuracy : 0.752 | Test accuracy : 0.640
# Epoch 325 | Train loss : 0.697 | Train accuracy : 0.751 | Test accuracy : 0.639
# Epoch 326 | Train loss : 0.687 | Train accuracy : 0.755 | Test accuracy : 0.642
# Epoch 327 | Train loss : 0.680 | Train accuracy : 0.755 | Test accuracy : 0.642
# Epoch 328 | Train loss : 0.682 | Train accuracy : 0.754 | Test accuracy : 0.640
# Epoch 329 | Train loss : 0.691 | Train accuracy : 0.753 | Test accuracy : 0.641
# Epoch 330 | Train loss : 0.704 | Train accuracy : 0.752 | Test accuracy : 0.640
# Epoch 331 | Train loss : 0.697 | Train accuracy : 0.752 | Test accuracy : 0.642
# Epoch 332 | Train loss : 0.713 | Train accuracy : 0.749 | Test accuracy : 0.638
# Epoch 333 | Train loss : 0.712 | Train accuracy : 0.749 | Test accuracy : 0.637
# Epoch 334 | Train loss : 0.720 | Train accuracy : 0.747 | Test accuracy : 0.637
# Epoch 335 | Train loss : 0.722 | Train accuracy : 0.746 | Test accuracy : 0.637
# Epoch 336 | Train loss : 0.722 | Train accuracy : 0.747 | Test accuracy : 0.636
# Epoch 337 | Train loss : 0.715 | Train accuracy : 0.749 | Test accuracy : 0.638
# Epoch 338 | Train loss : 0.722 | Train accuracy : 0.749 | Test accuracy : 0.638
# Epoch 339 | Train loss : 0.712 | Train accuracy : 0.751 | Test accuracy : 0.641
# Epoch 340 | Train loss : 0.719 | Train accuracy : 0.746 | Test accuracy : 0.639
# Epoch 341 | Train loss : 0.726 | Train accuracy : 0.747 | Test accuracy : 0.638
# Epoch 342 | Train loss : 0.716 | Train accuracy : 0.750 | Test accuracy : 0.640
# Epoch 343 | Train loss : 0.749 | Train accuracy : 0.744 | Test accuracy : 0.637
# Epoch 344 | Train loss : 0.725 | Train accuracy : 0.748 | Test accuracy : 0.640
# Epoch 345 | Train loss : 0.733 | Train accuracy : 0.747 | Test accuracy : 0.639
# Epoch 346 | Train loss : 0.727 | Train accuracy : 0.746 | Test accuracy : 0.638
# Epoch 347 | Train loss : 0.733 | Train accuracy : 0.747 | Test accuracy : 0.638
# Epoch 348 | Train loss : 0.728 | Train accuracy : 0.748 | Test accuracy : 0.640
# Epoch 349 | Train loss : 0.739 | Train accuracy : 0.747 | Test accuracy : 0.639
# Epoch 371 | Train loss : 0.726 | Train accuracy : 0.750 | Test accuracy : 0.640
# Epoch 372 | Train loss : 0.727 | Train accuracy : 0.749 | Test accuracy : 0.637
# Epoch 373 | Train loss : 0.705 | Train accuracy : 0.753 | Test accuracy : 0.641
# Epoch 374 | Train loss : 0.690 | Train accuracy : 0.757 | Test accuracy : 0.642
# Epoch 375 | Train loss : 0.712 | Train accuracy : 0.752 | Test accuracy : 0.641
# Epoch 376 | Train loss : 0.726 | Train accuracy : 0.750 | Test accuracy : 0.641
# Epoch 391 | Train loss : 0.727 | Train accuracy : 0.751 | Test accuracy : 0.642
# Epoch 392 | Train loss : 0.730 | Train accuracy : 0.749 | Test accuracy : 0.643
# Epoch 393 | Train loss : 0.733 | Train accuracy : 0.749 | Test accuracy : 0.644
# Epoch 394 | Train loss : 0.736 | Train accuracy : 0.749 | Test accuracy : 0.641
# Epoch 395 | Train loss : 0.741 | Train accuracy : 0.747 | Test accuracy : 0.641
# Epoch 396 | Train loss : 0.751 | Train accuracy : 0.748 | Test accuracy : 0.644
# Epoch 397 | Train loss : 0.727 | Train accuracy : 0.748 | Test accuracy : 0.639
# Epoch 398 | Train loss : 0.712 | Train accuracy : 0.752 | Test accuracy : 0.639
# Epoch 399 | Train loss : 0.722 | Train accuracy : 0.750 | Test accuracy : 0.637

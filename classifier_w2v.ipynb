# %%
import numpy as np
import pandas as pd

import torch
from torch import nn
from torch.nn import functional as F
from torch import optim
import time

from sklearn.metrics.pairwise import cosine_similarity
import ast

# %%
folder = '/dlabdata1/lugeon/'
name = 'websites_1000_5cat_emb.gz'
data = pd.read_csv(folder + name, 
                   header=0,
                   index_col = 0,
                   names=['emb', 'len', 'cat0'])

# %%
data.head()
# Out:
#                                                  emb  len  cat0
# 0                                                NaN    0  Arts
# 4  [0.06388844242802373, 0.022353509973596645, 0....  814  Arts
# 5  [0.04059564366060145, 0.030232969452353084, 0....  340  Arts
# 6  [-0.05609130859375, 0.06304931640625, -0.08801...    5  Arts
# 7  [-0.012737358085363795, 0.01617739857106969, 0...  584  Arts

# %%
data = data[data.emb.notnull()]
#data = data[data.len >= 100]

# %%
data['emb'] = data.apply(lambda row: np.array(ast.literal_eval(row.emb)), axis=1)

# %%
data.shape
# Out:
# (2653, 3)

# %%
data.cat0.value_counts()
# Out:
# Computers    626
# Arts         531
# Science      519
# Kids         503
# Sports       474
# Name: cat0, dtype: int64

# %%
def categorize(s):
    if s == 'Kids':
        return 0
    if s == 'Science':
        return 1
    if s == 'Arts':
        return 2
    if s == 'Computers':
        return 3
    if s == 'Sports':
        return 4

# %%
data['cat_no'] = data.apply(lambda row: categorize(row.cat0), axis=1)

# %%
embeddings = np.concatenate(data.emb.values)

# %%
embedding_dim = 300
train_input = torch.tensor(embeddings)
train_input = torch.reshape(train_input, (-1, embedding_dim)).float()

# %%
train_input.shape
# Out:
# torch.Size([2653, 300])

# %%
cat_no = data.cat_no.values
train_target = torch.tensor(cat_no).long()

# %%
train_target.shape
# Out:
# torch.Size([2653])

# %%
id = np.arange(train_input.shape[0])
np.random.shuffle(id)

training_set_size = 2_200

tr_id = id[:training_set_size]
te_id = id[training_set_size:]

train_input_ = train_input[tr_id]
test_input_ = train_input[te_id]

train_target_ = train_target[tr_id]
test_target_ = train_target[te_id]

# %%
data.iloc[tr_id].cat0.value_counts()
# Out:
# Computers    510
# Arts         443
# Science      425
# Kids         424
# Sports       398
# Name: cat0, dtype: int64

# %%
data.iloc[te_id].cat0.value_counts()
# Out:
# Computers    116
# Science       94
# Arts          88
# Kids          79
# Sports        76
# Name: cat0, dtype: int64

# %%
class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        self.fc1 = nn.Linear(300, 300)
        self.fc2 = nn.Linear(300, 300)
        self.fc3 = nn.Linear(300, 100)
        self.fc4 = nn.Linear(100, 5)
        self.drop = nn.Dropout(0.1)

    def forward(self, x):
        x = self.fc1(x)
        #x = self.drop(x)
        x = self.fc2(F.relu(x))
        # x = self.drop(x)
        x = self.fc3(F.relu(x))
        #x = self.drop(x)
        x = self.fc4(F.relu(x))
        return x

# %%
def accuracy(output, target):
    nb_samples = output.shape[0]
    
    # Convert probability to decision
    output_class = torch.argmax(output, 1)
    
    nb_correct = (output_class == target).sum().item()
    return nb_correct / nb_samples

# %%
epochs = 400
batch_size = 64

model = Classifier()

# Loss
criterion = nn.CrossEntropyLoss()

# Optimizer
optimizer = optim.Adam(model.parameters(), 1e-4)

# Training the model
model.train(True)

for e in range(epochs):
    
    for input, target in zip(train_input_.split(batch_size), train_target_.split(batch_size)):
                             
        output = model(input)
        loss = criterion(output, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    model.train(False)
    tr_output = model(train_input_)
    te_output = model(test_input_)
    tr_loss = criterion(tr_output, train_target_)
    tr_acc = accuracy(tr_output, train_target_)
    te_acc = accuracy(te_output, test_target_)
    model.train(True)
    print("Epoch {}".format(e) +\
          " | Train loss : {:.3f}".format(tr_loss) +\
          " | Train accuracy : {:.3f}".format(tr_acc) +\
          " | Test accuracy : {:.3f}".format(te_acc))
# Out:
# Epoch 0 | Train loss : 1.603 | Train accuracy : 0.345 | Test accuracy : 0.380
# Epoch 1 | Train loss : 1.594 | Train accuracy : 0.299 | Test accuracy : 0.344
# Epoch 2 | Train loss : 1.571 | Train accuracy : 0.374 | Test accuracy : 0.400
# Epoch 3 | Train loss : 1.519 | Train accuracy : 0.389 | Test accuracy : 0.417
# Epoch 4 | Train loss : 1.436 | Train accuracy : 0.466 | Test accuracy : 0.457
# Epoch 5 | Train loss : 1.360 | Train accuracy : 0.474 | Test accuracy : 0.448
# Epoch 6 | Train loss : 1.301 | Train accuracy : 0.505 | Test accuracy : 0.472
# Epoch 7 | Train loss : 1.248 | Train accuracy : 0.528 | Test accuracy : 0.506
# Epoch 8 | Train loss : 1.201 | Train accuracy : 0.545 | Test accuracy : 0.521
# Epoch 9 | Train loss : 1.161 | Train accuracy : 0.568 | Test accuracy : 0.530
# Epoch 10 | Train loss : 1.127 | Train accuracy : 0.586 | Test accuracy : 0.543
# Epoch 11 | Train loss : 1.098 | Train accuracy : 0.599 | Test accuracy : 0.550
# Epoch 12 | Train loss : 1.073 | Train accuracy : 0.615 | Test accuracy : 0.558
# Epoch 13 | Train loss : 1.050 | Train accuracy : 0.616 | Test accuracy : 0.565
# Epoch 14 | Train loss : 1.030 | Train accuracy : 0.624 | Test accuracy : 0.570
# Epoch 15 | Train loss : 1.011 | Train accuracy : 0.628 | Test accuracy : 0.576
# Epoch 16 | Train loss : 0.992 | Train accuracy : 0.635 | Test accuracy : 0.587
# Epoch 17 | Train loss : 0.974 | Train accuracy : 0.645 | Test accuracy : 0.587
# Epoch 18 | Train loss : 0.957 | Train accuracy : 0.652 | Test accuracy : 0.592
# Epoch 19 | Train loss : 0.940 | Train accuracy : 0.659 | Test accuracy : 0.598
# Epoch 20 | Train loss : 0.924 | Train accuracy : 0.662 | Test accuracy : 0.598
# Epoch 21 | Train loss : 0.908 | Train accuracy : 0.668 | Test accuracy : 0.605
# Epoch 22 | Train loss : 0.893 | Train accuracy : 0.672 | Test accuracy : 0.605
# Epoch 23 | Train loss : 0.879 | Train accuracy : 0.679 | Test accuracy : 0.607
# Epoch 24 | Train loss : 0.865 | Train accuracy : 0.681 | Test accuracy : 0.611
# Epoch 25 | Train loss : 0.852 | Train accuracy : 0.686 | Test accuracy : 0.623
# Epoch 26 | Train loss : 0.839 | Train accuracy : 0.689 | Test accuracy : 0.629
# Epoch 27 | Train loss : 0.827 | Train accuracy : 0.695 | Test accuracy : 0.636
# Epoch 28 | Train loss : 0.816 | Train accuracy : 0.697 | Test accuracy : 0.634
# Epoch 29 | Train loss : 0.805 | Train accuracy : 0.702 | Test accuracy : 0.634
# Epoch 30 | Train loss : 0.795 | Train accuracy : 0.702 | Test accuracy : 0.638
# Epoch 31 | Train loss : 0.785 | Train accuracy : 0.706 | Test accuracy : 0.636
# Epoch 32 | Train loss : 0.775 | Train accuracy : 0.712 | Test accuracy : 0.640
# Epoch 33 | Train loss : 0.766 | Train accuracy : 0.716 | Test accuracy : 0.642
# Epoch 34 | Train loss : 0.758 | Train accuracy : 0.722 | Test accuracy : 0.645
# Epoch 35 | Train loss : 0.749 | Train accuracy : 0.725 | Test accuracy : 0.645
# Epoch 36 | Train loss : 0.741 | Train accuracy : 0.730 | Test accuracy : 0.645
# Epoch 37 | Train loss : 0.734 | Train accuracy : 0.730 | Test accuracy : 0.645
# Epoch 38 | Train loss : 0.726 | Train accuracy : 0.734 | Test accuracy : 0.642
# Epoch 39 | Train loss : 0.719 | Train accuracy : 0.738 | Test accuracy : 0.640
# Epoch 40 | Train loss : 0.712 | Train accuracy : 0.742 | Test accuracy : 0.642
# Epoch 41 | Train loss : 0.705 | Train accuracy : 0.744 | Test accuracy : 0.642
# Epoch 42 | Train loss : 0.699 | Train accuracy : 0.745 | Test accuracy : 0.642
# Epoch 43 | Train loss : 0.693 | Train accuracy : 0.747 | Test accuracy : 0.640
# Epoch 44 | Train loss : 0.687 | Train accuracy : 0.749 | Test accuracy : 0.642
# Epoch 45 | Train loss : 0.681 | Train accuracy : 0.750 | Test accuracy : 0.642
# Epoch 46 | Train loss : 0.675 | Train accuracy : 0.752 | Test accuracy : 0.645
# Epoch 47 | Train loss : 0.669 | Train accuracy : 0.753 | Test accuracy : 0.642
# Epoch 48 | Train loss : 0.664 | Train accuracy : 0.756 | Test accuracy : 0.642
# Epoch 49 | Train loss : 0.659 | Train accuracy : 0.759 | Test accuracy : 0.642
# Epoch 50 | Train loss : 0.654 | Train accuracy : 0.760 | Test accuracy : 0.645
# Epoch 51 | Train loss : 0.648 | Train accuracy : 0.763 | Test accuracy : 0.645
# Epoch 52 | Train loss : 0.643 | Train accuracy : 0.764 | Test accuracy : 0.642
# Epoch 53 | Train loss : 0.638 | Train accuracy : 0.766 | Test accuracy : 0.649
# Epoch 54 | Train loss : 0.634 | Train accuracy : 0.768 | Test accuracy : 0.647
# Epoch 55 | Train loss : 0.629 | Train accuracy : 0.772 | Test accuracy : 0.645
# Epoch 56 | Train loss : 0.624 | Train accuracy : 0.775 | Test accuracy : 0.642
# Epoch 57 | Train loss : 0.620 | Train accuracy : 0.776 | Test accuracy : 0.647
# Epoch 58 | Train loss : 0.615 | Train accuracy : 0.778 | Test accuracy : 0.645
# Epoch 59 | Train loss : 0.611 | Train accuracy : 0.778 | Test accuracy : 0.640
# Epoch 60 | Train loss : 0.607 | Train accuracy : 0.780 | Test accuracy : 0.638
# Epoch 61 | Train loss : 0.602 | Train accuracy : 0.780 | Test accuracy : 0.638
# Epoch 62 | Train loss : 0.598 | Train accuracy : 0.782 | Test accuracy : 0.636
# Epoch 63 | Train loss : 0.594 | Train accuracy : 0.784 | Test accuracy : 0.636
# Epoch 64 | Train loss : 0.590 | Train accuracy : 0.787 | Test accuracy : 0.636
# Epoch 65 | Train loss : 0.586 | Train accuracy : 0.789 | Test accuracy : 0.636
# Epoch 66 | Train loss : 0.582 | Train accuracy : 0.789 | Test accuracy : 0.636
# Epoch 67 | Train loss : 0.578 | Train accuracy : 0.791 | Test accuracy : 0.636
# Epoch 68 | Train loss : 0.575 | Train accuracy : 0.793 | Test accuracy : 0.634
# Epoch 69 | Train loss : 0.571 | Train accuracy : 0.795 | Test accuracy : 0.634
# Epoch 70 | Train loss : 0.567 | Train accuracy : 0.797 | Test accuracy : 0.634
# Epoch 71 | Train loss : 0.563 | Train accuracy : 0.798 | Test accuracy : 0.634
# Epoch 72 | Train loss : 0.560 | Train accuracy : 0.799 | Test accuracy : 0.634
# Epoch 73 | Train loss : 0.556 | Train accuracy : 0.799 | Test accuracy : 0.634
# Epoch 74 | Train loss : 0.552 | Train accuracy : 0.801 | Test accuracy : 0.636
# Epoch 75 | Train loss : 0.549 | Train accuracy : 0.802 | Test accuracy : 0.636
# Epoch 76 | Train loss : 0.545 | Train accuracy : 0.803 | Test accuracy : 0.638
# Epoch 77 | Train loss : 0.542 | Train accuracy : 0.807 | Test accuracy : 0.640
# Epoch 78 | Train loss : 0.538 | Train accuracy : 0.806 | Test accuracy : 0.640
# Epoch 79 | Train loss : 0.535 | Train accuracy : 0.806 | Test accuracy : 0.640
# Epoch 80 | Train loss : 0.532 | Train accuracy : 0.809 | Test accuracy : 0.638
# Epoch 81 | Train loss : 0.528 | Train accuracy : 0.810 | Test accuracy : 0.640
# Epoch 82 | Train loss : 0.525 | Train accuracy : 0.813 | Test accuracy : 0.638
# Epoch 83 | Train loss : 0.522 | Train accuracy : 0.815 | Test accuracy : 0.638
# Epoch 84 | Train loss : 0.518 | Train accuracy : 0.816 | Test accuracy : 0.640
# Epoch 85 | Train loss : 0.515 | Train accuracy : 0.819 | Test accuracy : 0.640
# Epoch 86 | Train loss : 0.512 | Train accuracy : 0.820 | Test accuracy : 0.638
# Epoch 87 | Train loss : 0.509 | Train accuracy : 0.820 | Test accuracy : 0.638
# Epoch 88 | Train loss : 0.506 | Train accuracy : 0.821 | Test accuracy : 0.638
# Epoch 89 | Train loss : 0.502 | Train accuracy : 0.822 | Test accuracy : 0.638
# Epoch 90 | Train loss : 0.500 | Train accuracy : 0.823 | Test accuracy : 0.638
# Epoch 91 | Train loss : 0.496 | Train accuracy : 0.824 | Test accuracy : 0.636
# Epoch 92 | Train loss : 0.493 | Train accuracy : 0.825 | Test accuracy : 0.636
# Epoch 93 | Train loss : 0.490 | Train accuracy : 0.826 | Test accuracy : 0.636
# Epoch 94 | Train loss : 0.488 | Train accuracy : 0.827 | Test accuracy : 0.636
# Epoch 95 | Train loss : 0.485 | Train accuracy : 0.828 | Test accuracy : 0.636
# Epoch 96 | Train loss : 0.482 | Train accuracy : 0.828 | Test accuracy : 0.636
# Epoch 97 | Train loss : 0.479 | Train accuracy : 0.828 | Test accuracy : 0.636
# Epoch 98 | Train loss : 0.476 | Train accuracy : 0.830 | Test accuracy : 0.636
# Epoch 99 | Train loss : 0.473 | Train accuracy : 0.832 | Test accuracy : 0.638
# Epoch 100 | Train loss : 0.471 | Train accuracy : 0.835 | Test accuracy : 0.642
# Epoch 101 | Train loss : 0.468 | Train accuracy : 0.836 | Test accuracy : 0.640
# Epoch 102 | Train loss : 0.465 | Train accuracy : 0.836 | Test accuracy : 0.640
# Epoch 103 | Train loss : 0.462 | Train accuracy : 0.839 | Test accuracy : 0.642
# Epoch 104 | Train loss : 0.460 | Train accuracy : 0.838 | Test accuracy : 0.642
# Epoch 105 | Train loss : 0.457 | Train accuracy : 0.840 | Test accuracy : 0.640
# Epoch 106 | Train loss : 0.455 | Train accuracy : 0.840 | Test accuracy : 0.642
# Epoch 107 | Train loss : 0.452 | Train accuracy : 0.840 | Test accuracy : 0.640
# Epoch 108 | Train loss : 0.449 | Train accuracy : 0.841 | Test accuracy : 0.642
# Epoch 109 | Train loss : 0.447 | Train accuracy : 0.841 | Test accuracy : 0.640
# Epoch 110 | Train loss : 0.444 | Train accuracy : 0.842 | Test accuracy : 0.640
# Epoch 111 | Train loss : 0.442 | Train accuracy : 0.841 | Test accuracy : 0.638
# Epoch 112 | Train loss : 0.440 | Train accuracy : 0.842 | Test accuracy : 0.638
# Epoch 113 | Train loss : 0.437 | Train accuracy : 0.844 | Test accuracy : 0.640
# Epoch 114 | Train loss : 0.434 | Train accuracy : 0.845 | Test accuracy : 0.640
# Epoch 115 | Train loss : 0.432 | Train accuracy : 0.845 | Test accuracy : 0.636
# Epoch 116 | Train loss : 0.430 | Train accuracy : 0.845 | Test accuracy : 0.636
# Epoch 117 | Train loss : 0.427 | Train accuracy : 0.846 | Test accuracy : 0.636
# Epoch 118 | Train loss : 0.425 | Train accuracy : 0.847 | Test accuracy : 0.634
# Epoch 119 | Train loss : 0.423 | Train accuracy : 0.848 | Test accuracy : 0.636
# Epoch 120 | Train loss : 0.420 | Train accuracy : 0.848 | Test accuracy : 0.631
# Epoch 121 | Train loss : 0.418 | Train accuracy : 0.849 | Test accuracy : 0.631
# Epoch 122 | Train loss : 0.416 | Train accuracy : 0.849 | Test accuracy : 0.634
# Epoch 123 | Train loss : 0.413 | Train accuracy : 0.850 | Test accuracy : 0.634
# Epoch 124 | Train loss : 0.411 | Train accuracy : 0.850 | Test accuracy : 0.634
# Epoch 125 | Train loss : 0.409 | Train accuracy : 0.852 | Test accuracy : 0.634
# Epoch 126 | Train loss : 0.407 | Train accuracy : 0.853 | Test accuracy : 0.634
# Epoch 127 | Train loss : 0.405 | Train accuracy : 0.853 | Test accuracy : 0.634
# Epoch 128 | Train loss : 0.402 | Train accuracy : 0.855 | Test accuracy : 0.631
# Epoch 129 | Train loss : 0.400 | Train accuracy : 0.855 | Test accuracy : 0.631
# Epoch 130 | Train loss : 0.398 | Train accuracy : 0.855 | Test accuracy : 0.629
# Epoch 131 | Train loss : 0.396 | Train accuracy : 0.856 | Test accuracy : 0.627
# Epoch 132 | Train loss : 0.394 | Train accuracy : 0.857 | Test accuracy : 0.627
# Epoch 133 | Train loss : 0.392 | Train accuracy : 0.857 | Test accuracy : 0.627
# Epoch 134 | Train loss : 0.389 | Train accuracy : 0.859 | Test accuracy : 0.627
# Epoch 135 | Train loss : 0.387 | Train accuracy : 0.858 | Test accuracy : 0.625
# Epoch 136 | Train loss : 0.385 | Train accuracy : 0.858 | Test accuracy : 0.625
# Epoch 137 | Train loss : 0.383 | Train accuracy : 0.858 | Test accuracy : 0.625
# Epoch 138 | Train loss : 0.381 | Train accuracy : 0.860 | Test accuracy : 0.627
# Epoch 139 | Train loss : 0.379 | Train accuracy : 0.860 | Test accuracy : 0.625
# Epoch 140 | Train loss : 0.377 | Train accuracy : 0.863 | Test accuracy : 0.625
# Epoch 141 | Train loss : 0.375 | Train accuracy : 0.862 | Test accuracy : 0.623
# Epoch 142 | Train loss : 0.373 | Train accuracy : 0.863 | Test accuracy : 0.625
# Epoch 143 | Train loss : 0.371 | Train accuracy : 0.864 | Test accuracy : 0.625
# Epoch 144 | Train loss : 0.369 | Train accuracy : 0.866 | Test accuracy : 0.625
# Epoch 145 | Train loss : 0.367 | Train accuracy : 0.867 | Test accuracy : 0.625
# Epoch 146 | Train loss : 0.365 | Train accuracy : 0.868 | Test accuracy : 0.625
# Epoch 147 | Train loss : 0.363 | Train accuracy : 0.869 | Test accuracy : 0.625
# Epoch 148 | Train loss : 0.361 | Train accuracy : 0.870 | Test accuracy : 0.623
# Epoch 149 | Train loss : 0.359 | Train accuracy : 0.870 | Test accuracy : 0.623
# Epoch 150 | Train loss : 0.357 | Train accuracy : 0.871 | Test accuracy : 0.620
# Epoch 151 | Train loss : 0.355 | Train accuracy : 0.871 | Test accuracy : 0.618
# Epoch 152 | Train loss : 0.354 | Train accuracy : 0.872 | Test accuracy : 0.618
# Epoch 153 | Train loss : 0.352 | Train accuracy : 0.872 | Test accuracy : 0.620
# Epoch 154 | Train loss : 0.350 | Train accuracy : 0.874 | Test accuracy : 0.623
# Epoch 155 | Train loss : 0.349 | Train accuracy : 0.874 | Test accuracy : 0.623
# Epoch 156 | Train loss : 0.347 | Train accuracy : 0.874 | Test accuracy : 0.623
# Epoch 157 | Train loss : 0.346 | Train accuracy : 0.874 | Test accuracy : 0.625
# Epoch 158 | Train loss : 0.344 | Train accuracy : 0.874 | Test accuracy : 0.625
# Epoch 159 | Train loss : 0.342 | Train accuracy : 0.875 | Test accuracy : 0.625
# Epoch 160 | Train loss : 0.341 | Train accuracy : 0.875 | Test accuracy : 0.625
# Epoch 161 | Train loss : 0.339 | Train accuracy : 0.875 | Test accuracy : 0.625
# Epoch 162 | Train loss : 0.337 | Train accuracy : 0.875 | Test accuracy : 0.625
# Epoch 163 | Train loss : 0.335 | Train accuracy : 0.876 | Test accuracy : 0.625
# Epoch 164 | Train loss : 0.334 | Train accuracy : 0.877 | Test accuracy : 0.625
# Epoch 165 | Train loss : 0.332 | Train accuracy : 0.878 | Test accuracy : 0.627
# Epoch 166 | Train loss : 0.330 | Train accuracy : 0.878 | Test accuracy : 0.629
# Epoch 167 | Train loss : 0.328 | Train accuracy : 0.880 | Test accuracy : 0.629
# Epoch 168 | Train loss : 0.327 | Train accuracy : 0.883 | Test accuracy : 0.631
# Epoch 169 | Train loss : 0.326 | Train accuracy : 0.883 | Test accuracy : 0.629
# Epoch 170 | Train loss : 0.324 | Train accuracy : 0.883 | Test accuracy : 0.629
# Epoch 171 | Train loss : 0.322 | Train accuracy : 0.883 | Test accuracy : 0.631
# Epoch 172 | Train loss : 0.321 | Train accuracy : 0.884 | Test accuracy : 0.629
# Epoch 173 | Train loss : 0.320 | Train accuracy : 0.885 | Test accuracy : 0.629
# Epoch 174 | Train loss : 0.318 | Train accuracy : 0.885 | Test accuracy : 0.631
# Epoch 175 | Train loss : 0.316 | Train accuracy : 0.885 | Test accuracy : 0.631
# Epoch 176 | Train loss : 0.315 | Train accuracy : 0.886 | Test accuracy : 0.631
# Epoch 177 | Train loss : 0.314 | Train accuracy : 0.886 | Test accuracy : 0.631
# Epoch 178 | Train loss : 0.312 | Train accuracy : 0.887 | Test accuracy : 0.631
# Epoch 179 | Train loss : 0.310 | Train accuracy : 0.887 | Test accuracy : 0.631
# Epoch 180 | Train loss : 0.309 | Train accuracy : 0.890 | Test accuracy : 0.631
# Epoch 181 | Train loss : 0.308 | Train accuracy : 0.890 | Test accuracy : 0.631
# Epoch 182 | Train loss : 0.307 | Train accuracy : 0.891 | Test accuracy : 0.631
# Epoch 183 | Train loss : 0.305 | Train accuracy : 0.890 | Test accuracy : 0.631
# Epoch 184 | Train loss : 0.304 | Train accuracy : 0.891 | Test accuracy : 0.631
# Epoch 185 | Train loss : 0.302 | Train accuracy : 0.891 | Test accuracy : 0.629
# Epoch 186 | Train loss : 0.301 | Train accuracy : 0.894 | Test accuracy : 0.631
# Epoch 187 | Train loss : 0.299 | Train accuracy : 0.893 | Test accuracy : 0.634
# Epoch 188 | Train loss : 0.298 | Train accuracy : 0.893 | Test accuracy : 0.634
# Epoch 189 | Train loss : 0.296 | Train accuracy : 0.895 | Test accuracy : 0.634
# Epoch 190 | Train loss : 0.295 | Train accuracy : 0.896 | Test accuracy : 0.636
# Epoch 191 | Train loss : 0.294 | Train accuracy : 0.896 | Test accuracy : 0.634
# Epoch 192 | Train loss : 0.292 | Train accuracy : 0.898 | Test accuracy : 0.636
# Epoch 193 | Train loss : 0.291 | Train accuracy : 0.899 | Test accuracy : 0.634
# Epoch 194 | Train loss : 0.289 | Train accuracy : 0.899 | Test accuracy : 0.634
# Epoch 195 | Train loss : 0.289 | Train accuracy : 0.900 | Test accuracy : 0.634
# Epoch 196 | Train loss : 0.288 | Train accuracy : 0.900 | Test accuracy : 0.634
# Epoch 197 | Train loss : 0.286 | Train accuracy : 0.900 | Test accuracy : 0.636
# Epoch 198 | Train loss : 0.285 | Train accuracy : 0.901 | Test accuracy : 0.634
# Epoch 199 | Train loss : 0.284 | Train accuracy : 0.902 | Test accuracy : 0.631
# Epoch 200 | Train loss : 0.282 | Train accuracy : 0.902 | Test accuracy : 0.636
# Epoch 201 | Train loss : 0.281 | Train accuracy : 0.903 | Test accuracy : 0.634
# Epoch 202 | Train loss : 0.280 | Train accuracy : 0.902 | Test accuracy : 0.631
# Epoch 203 | Train loss : 0.278 | Train accuracy : 0.902 | Test accuracy : 0.631
# Epoch 204 | Train loss : 0.277 | Train accuracy : 0.903 | Test accuracy : 0.631
# Epoch 205 | Train loss : 0.276 | Train accuracy : 0.905 | Test accuracy : 0.629
# Epoch 206 | Train loss : 0.275 | Train accuracy : 0.904 | Test accuracy : 0.629
# Epoch 207 | Train loss : 0.274 | Train accuracy : 0.905 | Test accuracy : 0.629
# Epoch 208 | Train loss : 0.272 | Train accuracy : 0.905 | Test accuracy : 0.629
# Epoch 209 | Train loss : 0.271 | Train accuracy : 0.905 | Test accuracy : 0.629
# Epoch 210 | Train loss : 0.270 | Train accuracy : 0.905 | Test accuracy : 0.629
# Epoch 211 | Train loss : 0.269 | Train accuracy : 0.906 | Test accuracy : 0.629
# Epoch 212 | Train loss : 0.267 | Train accuracy : 0.906 | Test accuracy : 0.629
# Epoch 213 | Train loss : 0.267 | Train accuracy : 0.907 | Test accuracy : 0.629
# Epoch 214 | Train loss : 0.265 | Train accuracy : 0.907 | Test accuracy : 0.629
# Epoch 215 | Train loss : 0.264 | Train accuracy : 0.908 | Test accuracy : 0.629
# Epoch 216 | Train loss : 0.263 | Train accuracy : 0.908 | Test accuracy : 0.629
# Epoch 217 | Train loss : 0.262 | Train accuracy : 0.908 | Test accuracy : 0.629
# Epoch 218 | Train loss : 0.261 | Train accuracy : 0.908 | Test accuracy : 0.627
# Epoch 219 | Train loss : 0.259 | Train accuracy : 0.909 | Test accuracy : 0.627
# Epoch 220 | Train loss : 0.258 | Train accuracy : 0.909 | Test accuracy : 0.627
# Epoch 221 | Train loss : 0.257 | Train accuracy : 0.910 | Test accuracy : 0.627
# Epoch 222 | Train loss : 0.256 | Train accuracy : 0.910 | Test accuracy : 0.627
# Epoch 223 | Train loss : 0.255 | Train accuracy : 0.911 | Test accuracy : 0.627
# Epoch 224 | Train loss : 0.254 | Train accuracy : 0.911 | Test accuracy : 0.627
# Epoch 225 | Train loss : 0.253 | Train accuracy : 0.912 | Test accuracy : 0.627
# Epoch 226 | Train loss : 0.251 | Train accuracy : 0.912 | Test accuracy : 0.627
# Epoch 227 | Train loss : 0.251 | Train accuracy : 0.912 | Test accuracy : 0.625
# Epoch 228 | Train loss : 0.249 | Train accuracy : 0.913 | Test accuracy : 0.625
# Epoch 229 | Train loss : 0.248 | Train accuracy : 0.913 | Test accuracy : 0.625
# Epoch 230 | Train loss : 0.247 | Train accuracy : 0.914 | Test accuracy : 0.625
# Epoch 231 | Train loss : 0.246 | Train accuracy : 0.915 | Test accuracy : 0.625
# Epoch 232 | Train loss : 0.245 | Train accuracy : 0.915 | Test accuracy : 0.625
# Epoch 233 | Train loss : 0.244 | Train accuracy : 0.915 | Test accuracy : 0.625
# Epoch 234 | Train loss : 0.243 | Train accuracy : 0.915 | Test accuracy : 0.625
# Epoch 235 | Train loss : 0.242 | Train accuracy : 0.916 | Test accuracy : 0.627
# Epoch 236 | Train loss : 0.241 | Train accuracy : 0.916 | Test accuracy : 0.627
# Epoch 237 | Train loss : 0.240 | Train accuracy : 0.917 | Test accuracy : 0.627
# Epoch 238 | Train loss : 0.240 | Train accuracy : 0.917 | Test accuracy : 0.625
# Epoch 239 | Train loss : 0.238 | Train accuracy : 0.917 | Test accuracy : 0.627
# Epoch 240 | Train loss : 0.238 | Train accuracy : 0.918 | Test accuracy : 0.627
# Epoch 241 | Train loss : 0.237 | Train accuracy : 0.918 | Test accuracy : 0.625
# Epoch 242 | Train loss : 0.236 | Train accuracy : 0.919 | Test accuracy : 0.625
# Epoch 243 | Train loss : 0.235 | Train accuracy : 0.919 | Test accuracy : 0.627
# Epoch 244 | Train loss : 0.234 | Train accuracy : 0.919 | Test accuracy : 0.625
# Epoch 245 | Train loss : 0.233 | Train accuracy : 0.919 | Test accuracy : 0.627
# Epoch 246 | Train loss : 0.232 | Train accuracy : 0.920 | Test accuracy : 0.627
# Epoch 247 | Train loss : 0.232 | Train accuracy : 0.920 | Test accuracy : 0.625
# Epoch 248 | Train loss : 0.230 | Train accuracy : 0.920 | Test accuracy : 0.625
# Epoch 249 | Train loss : 0.229 | Train accuracy : 0.920 | Test accuracy : 0.625
# Epoch 250 | Train loss : 0.229 | Train accuracy : 0.920 | Test accuracy : 0.625
# Epoch 251 | Train loss : 0.228 | Train accuracy : 0.921 | Test accuracy : 0.627
# Epoch 252 | Train loss : 0.227 | Train accuracy : 0.921 | Test accuracy : 0.625
# Epoch 253 | Train loss : 0.226 | Train accuracy : 0.921 | Test accuracy : 0.625
# Epoch 254 | Train loss : 0.225 | Train accuracy : 0.921 | Test accuracy : 0.625
# Epoch 255 | Train loss : 0.225 | Train accuracy : 0.921 | Test accuracy : 0.625
# Epoch 256 | Train loss : 0.224 | Train accuracy : 0.921 | Test accuracy : 0.625
# Epoch 257 | Train loss : 0.223 | Train accuracy : 0.921 | Test accuracy : 0.625
# Epoch 258 | Train loss : 0.222 | Train accuracy : 0.922 | Test accuracy : 0.625
# Epoch 259 | Train loss : 0.221 | Train accuracy : 0.923 | Test accuracy : 0.625
# Epoch 260 | Train loss : 0.221 | Train accuracy : 0.922 | Test accuracy : 0.625
# Epoch 261 | Train loss : 0.220 | Train accuracy : 0.924 | Test accuracy : 0.625
# Epoch 262 | Train loss : 0.219 | Train accuracy : 0.924 | Test accuracy : 0.627
# Epoch 263 | Train loss : 0.218 | Train accuracy : 0.924 | Test accuracy : 0.627
# Epoch 264 | Train loss : 0.217 | Train accuracy : 0.924 | Test accuracy : 0.627
# Epoch 265 | Train loss : 0.217 | Train accuracy : 0.924 | Test accuracy : 0.627
# Epoch 266 | Train loss : 0.216 | Train accuracy : 0.924 | Test accuracy : 0.627
# Epoch 267 | Train loss : 0.215 | Train accuracy : 0.924 | Test accuracy : 0.627
# Epoch 268 | Train loss : 0.214 | Train accuracy : 0.924 | Test accuracy : 0.627
# Epoch 269 | Train loss : 0.214 | Train accuracy : 0.925 | Test accuracy : 0.629
# Epoch 270 | Train loss : 0.213 | Train accuracy : 0.925 | Test accuracy : 0.627
# Epoch 271 | Train loss : 0.213 | Train accuracy : 0.925 | Test accuracy : 0.627
# Epoch 272 | Train loss : 0.211 | Train accuracy : 0.925 | Test accuracy : 0.627
# Epoch 273 | Train loss : 0.211 | Train accuracy : 0.925 | Test accuracy : 0.629
# Epoch 274 | Train loss : 0.210 | Train accuracy : 0.925 | Test accuracy : 0.629
# Epoch 275 | Train loss : 0.209 | Train accuracy : 0.925 | Test accuracy : 0.629
# Epoch 276 | Train loss : 0.208 | Train accuracy : 0.925 | Test accuracy : 0.629
# Epoch 277 | Train loss : 0.208 | Train accuracy : 0.925 | Test accuracy : 0.634
# Epoch 278 | Train loss : 0.207 | Train accuracy : 0.925 | Test accuracy : 0.634
# Epoch 279 | Train loss : 0.207 | Train accuracy : 0.925 | Test accuracy : 0.631
# Epoch 280 | Train loss : 0.206 | Train accuracy : 0.925 | Test accuracy : 0.634
# Epoch 281 | Train loss : 0.205 | Train accuracy : 0.926 | Test accuracy : 0.634
# Epoch 282 | Train loss : 0.205 | Train accuracy : 0.926 | Test accuracy : 0.634
# Epoch 283 | Train loss : 0.203 | Train accuracy : 0.926 | Test accuracy : 0.631
# Epoch 284 | Train loss : 0.203 | Train accuracy : 0.927 | Test accuracy : 0.634
# Epoch 285 | Train loss : 0.203 | Train accuracy : 0.927 | Test accuracy : 0.631
# Epoch 286 | Train loss : 0.202 | Train accuracy : 0.928 | Test accuracy : 0.631
# Epoch 287 | Train loss : 0.201 | Train accuracy : 0.928 | Test accuracy : 0.631
# Epoch 288 | Train loss : 0.200 | Train accuracy : 0.928 | Test accuracy : 0.634
# Epoch 289 | Train loss : 0.200 | Train accuracy : 0.928 | Test accuracy : 0.631
# Epoch 290 | Train loss : 0.199 | Train accuracy : 0.928 | Test accuracy : 0.631
# Epoch 291 | Train loss : 0.198 | Train accuracy : 0.929 | Test accuracy : 0.631
# Epoch 292 | Train loss : 0.198 | Train accuracy : 0.929 | Test accuracy : 0.634
# Epoch 293 | Train loss : 0.197 | Train accuracy : 0.930 | Test accuracy : 0.634
# Epoch 294 | Train loss : 0.196 | Train accuracy : 0.930 | Test accuracy : 0.634
# Epoch 295 | Train loss : 0.196 | Train accuracy : 0.930 | Test accuracy : 0.634
# Epoch 296 | Train loss : 0.195 | Train accuracy : 0.930 | Test accuracy : 0.631
# Epoch 297 | Train loss : 0.194 | Train accuracy : 0.930 | Test accuracy : 0.634
# Epoch 298 | Train loss : 0.194 | Train accuracy : 0.930 | Test accuracy : 0.631
# Epoch 299 | Train loss : 0.193 | Train accuracy : 0.930 | Test accuracy : 0.634
# Epoch 300 | Train loss : 0.193 | Train accuracy : 0.930 | Test accuracy : 0.634
# Epoch 301 | Train loss : 0.193 | Train accuracy : 0.930 | Test accuracy : 0.634
# Epoch 302 | Train loss : 0.192 | Train accuracy : 0.930 | Test accuracy : 0.634
# Epoch 303 | Train loss : 0.191 | Train accuracy : 0.930 | Test accuracy : 0.634
# Epoch 304 | Train loss : 0.191 | Train accuracy : 0.930 | Test accuracy : 0.634
# Epoch 305 | Train loss : 0.190 | Train accuracy : 0.930 | Test accuracy : 0.634
# Epoch 306 | Train loss : 0.190 | Train accuracy : 0.930 | Test accuracy : 0.634
# Epoch 307 | Train loss : 0.189 | Train accuracy : 0.930 | Test accuracy : 0.631
# Epoch 308 | Train loss : 0.189 | Train accuracy : 0.930 | Test accuracy : 0.634
# Epoch 309 | Train loss : 0.188 | Train accuracy : 0.931 | Test accuracy : 0.631
# Epoch 310 | Train loss : 0.187 | Train accuracy : 0.931 | Test accuracy : 0.631
# Epoch 311 | Train loss : 0.187 | Train accuracy : 0.931 | Test accuracy : 0.631
# Epoch 312 | Train loss : 0.186 | Train accuracy : 0.931 | Test accuracy : 0.631
# Epoch 313 | Train loss : 0.186 | Train accuracy : 0.930 | Test accuracy : 0.631
# Epoch 314 | Train loss : 0.185 | Train accuracy : 0.931 | Test accuracy : 0.631
# Epoch 315 | Train loss : 0.185 | Train accuracy : 0.931 | Test accuracy : 0.631
# Epoch 316 | Train loss : 0.184 | Train accuracy : 0.932 | Test accuracy : 0.631
# Epoch 317 | Train loss : 0.184 | Train accuracy : 0.932 | Test accuracy : 0.631
# Epoch 318 | Train loss : 0.184 | Train accuracy : 0.931 | Test accuracy : 0.631
# Epoch 319 | Train loss : 0.183 | Train accuracy : 0.932 | Test accuracy : 0.631
# Epoch 320 | Train loss : 0.183 | Train accuracy : 0.932 | Test accuracy : 0.631
# Epoch 321 | Train loss : 0.182 | Train accuracy : 0.933 | Test accuracy : 0.631
# Epoch 322 | Train loss : 0.182 | Train accuracy : 0.932 | Test accuracy : 0.631
# Epoch 323 | Train loss : 0.181 | Train accuracy : 0.932 | Test accuracy : 0.631
# Epoch 324 | Train loss : 0.181 | Train accuracy : 0.932 | Test accuracy : 0.631
# Epoch 325 | Train loss : 0.181 | Train accuracy : 0.933 | Test accuracy : 0.631
# Epoch 326 | Train loss : 0.180 | Train accuracy : 0.933 | Test accuracy : 0.631
# Epoch 327 | Train loss : 0.180 | Train accuracy : 0.932 | Test accuracy : 0.631
# Epoch 328 | Train loss : 0.180 | Train accuracy : 0.933 | Test accuracy : 0.631
# Epoch 329 | Train loss : 0.179 | Train accuracy : 0.933 | Test accuracy : 0.631
# Epoch 330 | Train loss : 0.179 | Train accuracy : 0.934 | Test accuracy : 0.629
# Epoch 331 | Train loss : 0.179 | Train accuracy : 0.933 | Test accuracy : 0.631
# Epoch 332 | Train loss : 0.178 | Train accuracy : 0.933 | Test accuracy : 0.631
# Epoch 333 | Train loss : 0.178 | Train accuracy : 0.934 | Test accuracy : 0.629
# Epoch 334 | Train loss : 0.177 | Train accuracy : 0.935 | Test accuracy : 0.631
# Epoch 335 | Train loss : 0.177 | Train accuracy : 0.935 | Test accuracy : 0.631
# Epoch 336 | Train loss : 0.176 | Train accuracy : 0.934 | Test accuracy : 0.634
# Epoch 337 | Train loss : 0.176 | Train accuracy : 0.935 | Test accuracy : 0.631
# Epoch 338 | Train loss : 0.176 | Train accuracy : 0.935 | Test accuracy : 0.631
# Epoch 339 | Train loss : 0.175 | Train accuracy : 0.934 | Test accuracy : 0.634
# Epoch 340 | Train loss : 0.175 | Train accuracy : 0.935 | Test accuracy : 0.634
# Epoch 341 | Train loss : 0.175 | Train accuracy : 0.935 | Test accuracy : 0.634
# Epoch 342 | Train loss : 0.174 | Train accuracy : 0.935 | Test accuracy : 0.634
# Epoch 343 | Train loss : 0.174 | Train accuracy : 0.935 | Test accuracy : 0.634
# Epoch 344 | Train loss : 0.174 | Train accuracy : 0.936 | Test accuracy : 0.631
# Epoch 345 | Train loss : 0.173 | Train accuracy : 0.936 | Test accuracy : 0.631
# Epoch 346 | Train loss : 0.173 | Train accuracy : 0.936 | Test accuracy : 0.631
# Epoch 347 | Train loss : 0.173 | Train accuracy : 0.937 | Test accuracy : 0.631
# Epoch 348 | Train loss : 0.173 | Train accuracy : 0.936 | Test accuracy : 0.629
# Epoch 349 | Train loss : 0.172 | Train accuracy : 0.936 | Test accuracy : 0.631
# Epoch 350 | Train loss : 0.172 | Train accuracy : 0.936 | Test accuracy : 0.631
# Epoch 351 | Train loss : 0.171 | Train accuracy : 0.936 | Test accuracy : 0.631
# Epoch 352 | Train loss : 0.171 | Train accuracy : 0.936 | Test accuracy : 0.636
# Epoch 353 | Train loss : 0.171 | Train accuracy : 0.936 | Test accuracy : 0.631
# Epoch 354 | Train loss : 0.171 | Train accuracy : 0.936 | Test accuracy : 0.634
# Epoch 355 | Train loss : 0.170 | Train accuracy : 0.935 | Test accuracy : 0.634
# Epoch 356 | Train loss : 0.170 | Train accuracy : 0.936 | Test accuracy : 0.634
# Epoch 357 | Train loss : 0.170 | Train accuracy : 0.935 | Test accuracy : 0.634
# Epoch 358 | Train loss : 0.170 | Train accuracy : 0.935 | Test accuracy : 0.631
# Epoch 359 | Train loss : 0.169 | Train accuracy : 0.935 | Test accuracy : 0.634
# Epoch 360 | Train loss : 0.169 | Train accuracy : 0.936 | Test accuracy : 0.629
# Epoch 361 | Train loss : 0.169 | Train accuracy : 0.935 | Test accuracy : 0.631
# Epoch 362 | Train loss : 0.169 | Train accuracy : 0.935 | Test accuracy : 0.631
# Epoch 363 | Train loss : 0.168 | Train accuracy : 0.935 | Test accuracy : 0.631
# Epoch 364 | Train loss : 0.168 | Train accuracy : 0.935 | Test accuracy : 0.634
# Epoch 365 | Train loss : 0.168 | Train accuracy : 0.936 | Test accuracy : 0.631
# Epoch 366 | Train loss : 0.167 | Train accuracy : 0.936 | Test accuracy : 0.629
# Epoch 367 | Train loss : 0.167 | Train accuracy : 0.937 | Test accuracy : 0.627
# Epoch 368 | Train loss : 0.167 | Train accuracy : 0.937 | Test accuracy : 0.631
# Epoch 369 | Train loss : 0.166 | Train accuracy : 0.937 | Test accuracy : 0.629
# Epoch 370 | Train loss : 0.167 | Train accuracy : 0.937 | Test accuracy : 0.627
# Epoch 371 | Train loss : 0.166 | Train accuracy : 0.937 | Test accuracy : 0.629
# Epoch 372 | Train loss : 0.166 | Train accuracy : 0.937 | Test accuracy : 0.629
# Epoch 373 | Train loss : 0.166 | Train accuracy : 0.937 | Test accuracy : 0.629
# Epoch 374 | Train loss : 0.166 | Train accuracy : 0.937 | Test accuracy : 0.629
# Epoch 375 | Train loss : 0.165 | Train accuracy : 0.937 | Test accuracy : 0.629
# Epoch 376 | Train loss : 0.165 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 377 | Train loss : 0.164 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 378 | Train loss : 0.165 | Train accuracy : 0.937 | Test accuracy : 0.629
# Epoch 379 | Train loss : 0.164 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 380 | Train loss : 0.164 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 381 | Train loss : 0.163 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 382 | Train loss : 0.163 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 383 | Train loss : 0.162 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 384 | Train loss : 0.162 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 385 | Train loss : 0.162 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 386 | Train loss : 0.162 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 387 | Train loss : 0.161 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 388 | Train loss : 0.161 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 389 | Train loss : 0.161 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 390 | Train loss : 0.161 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 391 | Train loss : 0.160 | Train accuracy : 0.938 | Test accuracy : 0.629
# Epoch 392 | Train loss : 0.160 | Train accuracy : 0.939 | Test accuracy : 0.629
# Epoch 393 | Train loss : 0.160 | Train accuracy : 0.939 | Test accuracy : 0.629
# Epoch 394 | Train loss : 0.159 | Train accuracy : 0.939 | Test accuracy : 0.629
# Epoch 395 | Train loss : 0.159 | Train accuracy : 0.940 | Test accuracy : 0.629
# Epoch 396 | Train loss : 0.159 | Train accuracy : 0.940 | Test accuracy : 0.629
# Epoch 397 | Train loss : 0.159 | Train accuracy : 0.939 | Test accuracy : 0.629
# Epoch 398 | Train loss : 0.158 | Train accuracy : 0.940 | Test accuracy : 0.629
# Epoch 399 | Train loss : 0.158 | Train accuracy : 0.940 | Test accuracy : 0.629
